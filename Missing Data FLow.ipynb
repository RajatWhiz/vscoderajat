# %%
import pandas as pd
import gc
import numpy as np

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
temp = pd.read_csv('/home/rajatsharma/DSA/Files.csv',low_memory=False,chunksize=10000)
df = pd.concat(temp)
del temp
gc.collect()
# Out:
# 0

# %%
to_drop = ['Unnamed: 0','id','type','host','path','timestamp','@timestamp','@version']+[i for i in df.columns if 'layer.eth' in i]+ [i for i in df.columns if 'layer.json' in i]
df = df.drop(to_drop,axis = 1)
del to_drop
gc.collect()

# %%
df = df.drop('Unnamed: 0',axis =1)

# %%
df.isnull().sum()*100/len(df)
# Out:
# layer.ip.ip.src_host                                                     0.147059
# layer.http._ws.expert.message                                           83.741758
# layer.ssl.x509af.signedCertificate_element                              99.886267
# layer.icmp.ip.dst_host                                                  99.982279
# layer.dns.dns.flags.z                                                   98.744971
# layer.ssl.ssl.handshake.extensions_status_request_list_len              99.889177
# layer.sip.sip.User-Agent                                                99.987833
# layer.sip.sip.to.user                                                   99.987304
# layer.dns.dns.flags.opcode                                              98.744971
# layer.icmp.dns.count.auth_rr                                            99.998149
# layer.icmp.sip.r-uri.host                                               99.998678
# ...
